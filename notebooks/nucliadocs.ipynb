# %% [markdown]
# # Install

# %%
#!nuclia auth login

# %%
#%pip install -qU nuclia tdqm requests

# %% [markdown]
# # Import

# %%
from nuclia import sdk
import os
# Out:
# c:\Users\aflon\OneDrive\Documentos\GitHub\RAG-Knowledge-Graph\.venv\lib\site-packages\pydantic\_internal\_fields.py:192: UserWarning: Field name "json" in "AskOperation" shadows an attribute in parent "BaseModel"
#   warnings.warn(

# %% [markdown]
# # Env Variables

# %%
USER_TOKEN = os.getenv('NUCLIA_USER_TOKEN')
KB_URL = os.getenv('NUCLIA_KB_URL')
KB_ID = os.getenv('NUCLIA_KB_ID')
API_KEY = os.getenv('NUCLIA_API_KEY')

# %% [markdown]
# # Auth

# %%
sdk.NucliaAuth().set_user_token(USER_TOKEN)

# %%
#sdk.NucliaAuth().create_personal_token(description="Testingv2", days=30)
sdk.NucliaAuth().list_personal_tokens()
# Out:
# [PersonalTokenItem(id='54457eac-ec50-420a-89dc-f7a48b9b463e', description='Testingv2', expires=datetime.datetime(2025, 4, 3, 9, 44, 55, 485220))]

# %%
sdk.NucliaAuth().kb(url=KB_URL, token=API_KEY)
# Out:
# '3aa88834-0641-4367-8994-985a86f01e55'

# %%
kbs = sdk.NucliaKBS()
kbs.list()
# Out:
# Connection error to https://aws-eu-south-2-1.nuclia.cloud, skipping zone
# [KnowledgeBox(id='3aa88834-0641-4367-8994-985a86f01e55', url='https://europe-1.nuclia.cloud/api/v1/kb/3aa88834-0641-4367-8994-985a86f01e55', title='PIA - UPC', slug='pia---upc', token=None, region='europe-1', account='37922852-1488-4882-ac9b-c9a02669e60c'),
#  KnowledgeBox(id='3aa88834-0641-4367-8994-985a86f01e55', url='https://europe-1.nuclia.cloud/api/v1/kb/3aa88834-0641-4367-8994-985a86f01e55', title='PIA - UPC', slug=None, token='eyJhbGciOiJSUzI1NiIsImtpZCI6InNhIiwidHlwIjoiSldUIn0..GhKLX60KUstEPWjkpuwUj2cUNrBREiBjwCZxzwTOLnwN8ztyjYkXnMG8HYN_Vwr6eHUHcaqGvcVw-P2OXeVfq6srYyHb1mzXu7qFWmmQpiW4Qthsuj8b5iuPO5Ye9Cb1iWTuXRSiDu4bID3MycsbIdajFKAuWuctLWZWz-yXJ-pTpeOxi1zooBL6AA_m8njVqfoGjdNQLkmsBLi6RFOyKvNKfcQ-9UQSrNxn_529mGbot73qefF2Hx4mSoP6u_bprDN9IL2qZeJmFS9voPLahYvj8nS54A2cuS4_DLHD65ftvpeviACfweXdfnc5Jm3i4BMMoArXmUpLXbzy9OYHOSsbb7Kfg1uUtM70c6LvOqgpPHx9HYSEruJZVRuVhPDNRuElFT_kQ-3y1KKh1Xfqeb8x9udXoZs2L5pIspTOxlALOrjeDP7nU7HCv2wZ3n8miZEMRdBLLPrPymqxLXh3QfZ_qXtDIYwdnkrPLZFUl0E8igImq4-WVaIOdZnCf5ezjXL1bBTYWkck6B0pjweULdpFv9-iLAQg3hgrzizIPP5NZ6NEOS9l5IHhTUIxiP-QtztaHODwxK4G7-hQyIuzVdSIIrHWbaSEsB9f2OG9SMGrwAumgX-SqpbgjqVn8Xdc0PWNwZZW-Ql1nEUaM4rdR5auTRfEyjZjcAB5GBvxCnc', region='europe-1', account=None)]

# %%
kbs.default(KB_ID)

# %%
kb = sdk.NucliaKB()
resources = kb.list(page=0, size=10)

# %%
resources
# Out:
# ResourceList(resources=[Resource(id='122bb3251be909d96d571c8eb26bdb0d', slug='122bb3251be909d96d571c8eb26bdb0d', title='2022 Q3 AAPL.pdf', summary='', icon='application/pdf', thumbnail='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/122bb3251be909d96d571c8eb26bdb0d/file/122bb3251be909d96d571c8eb26bdb0d/download/extracted/file_thumbnail', metadata=Metadata(metadata={}, language='en', languages=['en', 'zh'], status=<ResourceProcessingStatus.PROCESSED: 'PROCESSED'>), usermetadata=UserMetadata(classifications=[], relations=[]), fieldmetadata=[], computedmetadata=ComputedMetadata(field_classifications=[]), created=datetime.datetime(2025, 3, 4, 8, 51, 6, 159374), modified=None, last_seqid=0, last_account_seq=None, queue=<QueueType.PRIVATE: 'private'>, hidden=False, origin=None, extra=None, relations=None, data=None, security=None), Resource(id='15b46c0690d7d712e10ac7e9249cb6b0', slug='15b46c0690d7d712e10ac7e9249cb6b0', title='2023 Q1 MSFT.pdf', summary='', icon='application/pdf', thumbnail='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/15b46c0690d7d712e10ac7e9249cb6b0/file/15b46c0690d7d712e10ac7e9249cb6b0/download/extracted/file_thumbnail', metadata=Metadata(metadata={}, language='en', languages=['en'], status=<ResourceProcessingStatus.PROCESSED: 'PROCESSED'>), usermetadata=UserMetadata(classifications=[], relations=[]), fieldmetadata=[], computedmetadata=ComputedMetadata(field_classifications=[]), created=datetime.datetime(2025, 3, 4, 8, 51, 8, 72071), modified=None, last_seqid=0, last_account_seq=None, queue=<QueueType.PRIVATE: 'private'>, hidden=False, origin=None, extra=None, relations=None, data=None, security=None), Resource(id='1fb9be2040ab9fee044108559d76d180', slug='1fb9be2040ab9fee044108559d76d180', title='2022 Q3 MSFT.pdf', summary='', icon='application/pdf', thumbnail='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/1fb9be2040ab9fee044108559d76d180/file/1fb9be2040ab9fee044108559d76d180/download/extracted/file_thumbnail', metadata=Metadata(metadata={}, language='en', languages=['en'], status=<ResourceProcessingStatus.PROCESSED: 'PROCESSED'>), usermetadata=UserMetadata(classifications=[], relations=[]), fieldmetadata=[], computedmetadata=ComputedMetadata(field_classifications=[]), created=datetime.datetime(2025, 3, 4, 8, 51, 7, 124241), modified=None, last_seqid=0, last_account_seq=None, queue=<QueueType.PRIVATE: 'private'>, hidden=False, origin=None, extra=None, relations=None, data=None, security=None), Resource(id='2c6d707be547d4c782155dab5f345ea6', slug='2c6d707be547d4c782155dab5f345ea6', title='2023 Q3 MSFT.pdf', summary='', icon='application/pdf', thumbnail='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/2c6d707be547d4c782155dab5f345ea6/file/2c6d707be547d4c782155dab5f345ea6/download/extracted/file_thumbnail', metadata=Metadata(metadata={}, language='en', languages=['en'], status=<ResourceProcessingStatus.PROCESSED: 'PROCESSED'>), usermetadata=UserMetadata(classifications=[], relations=[]), fieldmetadata=[], computedmetadata=ComputedMetadata(field_classifications=[]), created=datetime.datetime(2025, 3, 4, 8, 51, 10, 166419), modified=None, last_seqid=0, last_account_seq=None, queue=<QueueType.PRIVATE: 'private'>, hidden=False, origin=None, extra=None, relations=None, data=None, security=None), Resource(id='3be70c327392873c90d1ec326efd18b2', slug='3be70c327392873c90d1ec326efd18b2', title='2023 Q1 AMZN.pdf', summary='', icon='application/pdf', thumbnail='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/3be70c327392873c90d1ec326efd18b2/file/3be70c327392873c90d1ec326efd18b2/download/extracted/file_thumbnail', metadata=Metadata(metadata={}, language='en', languages=['en', 'es'], status=<ResourceProcessingStatus.PROCESSED: 'PROCESSED'>), usermetadata=UserMetadata(classifications=[], relations=[]), fieldmetadata=[], computedmetadata=ComputedMetadata(field_classifications=[]), created=datetime.datetime(2025, 3, 4, 8, 51, 7, 333759), modified=None, last_seqid=0, last_account_seq=None, queue=<QueueType.PRIVATE: 'pr ...

# %%
# Create a Reource
"""
res = sdk.NucliaResource()
res.create(
  slug="my-resource",
  usermetadata={
    "classifications": [
        {"labelset": "subjects", "label": "<Topic 1>"},
        {"labelset": "subjects", "label": "<Topic 2>"},
    ],
  },
  texts={"chapter-1": {"body": "here is a test", "format": "PLAIN"}},
)
"""
# Out:
# '\nres = sdk.NucliaResource()\nres.create(\n  slug="my-resource",\n  usermetadata={\n    "classifications": [\n        {"labelset": "subjects", "label": "<Topic 1>"},\n        {"labelset": "subjects", "label": "<Topic 2>"},\n    ],\n  },\n  texts={"chapter-1": {"body": "here is a test", "format": "PLAIN"}},\n)\n'

# %%
RID="122bb3251be909d96d571c8eb26bdb0d"

# %%
# Get a Resource specifying its ID
resource = sdk.NucliaResource()
resource.get(rid=RID, show=["basic", "values"])
# Out:
# Resource(id='122bb3251be909d96d571c8eb26bdb0d', slug='122bb3251be909d96d571c8eb26bdb0d', title='2022 Q3 AAPL.pdf', summary='', icon='application/pdf', thumbnail='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/122bb3251be909d96d571c8eb26bdb0d/file/122bb3251be909d96d571c8eb26bdb0d/download/extracted/file_thumbnail', metadata=Metadata(metadata={}, language='en', languages=['en', 'zh'], status=<ResourceProcessingStatus.PROCESSED: 'PROCESSED'>), usermetadata=UserMetadata(classifications=[], relations=[]), fieldmetadata=[], computedmetadata=ComputedMetadata(field_classifications=[]), created=datetime.datetime(2025, 3, 4, 8, 51, 6, 159374), modified=None, last_seqid=0, last_account_seq=None, queue=<QueueType.PRIVATE: 'private'>, hidden=False, origin=None, extra=None, relations=None, data=ResourceData(texts=None, files={'122bb3251be909d96d571c8eb26bdb0d': FileFieldData(value=FieldFile(added=datetime.datetime(2025, 3, 4, 8, 51, 6, 159399, tzinfo=TzInfo(UTC)), file=CloudLink(uri='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/122bb3251be909d96d571c8eb26bdb0d/file/122bb3251be909d96d571c8eb26bdb0d/download/field', size=266240, content_type='application/pdf', filename='2022%20Q3%20AAPL.pdf', md5='122bb3251be909d96d571c8eb26bdb0d'), language='', password='', external=False, extract_strategy=''), extracted=None, error=None, status=None, errors=None)}, links=None, conversations=None, generics={'title': GenericFieldData(value='2022 Q3 AAPL.pdf', extracted=None, error=None, status=None, errors=None)}), security=None)

# %%
FIELD_ID="chapter-1"

# %%
# Download a Resource specifying its ID

"""
resource.download_file(rid=RID, file_id=FIELD_ID, output="./my-file.pdf")
"""
# Out:
# '\nresource.download_file(rid=RID, file_id=FIELD_ID, output="./my-file.pdf")\n'

# %%
# Delete a Resource specifying its ID
    
"""
resource.delete(rid=RID)
"""
# Out:
# '\nresource.delete(rid=RID)\n'

# %%
# Examining the Resource
attributes = [attr for attr in dir(resource) if not callable(getattr(resource,attr)) and not attr.startswith('_')]
methods = [method for method in dir(resource) if callable(getattr(resource,method)) and not method.startswith('_')]

print("Attributes: ", attributes)
print("Methods: ", methods)
# Out:
# Attributes:  []
# Methods:  ['ask', 'create', 'delete', 'download_file', 'get', 'send_to_process', 'update']

# %%
extracted = resource.get(rid=RID, show=["extracted"])

# %%
import sys
from pprint import pprint

output_file = "knowledge_graph.txt"

# Open the file in write mode
with open(output_file, "w", encoding="utf-8") as f:
    # Print to both console and file
    pprint(extracted, depth=3, stream=f)  # Write to file
    pprint(extracted, depth=3)  # Print to notebook console

print(f"Knowledge Graph saved to {output_file}")
# Out:
# Resource(id='122bb3251be909d96d571c8eb26bdb0d', slug='122bb3251be909d96d571c8eb26bdb0d', title='2022 Q3 AAPL.pdf', summary='', icon='application/pdf', thumbnail='/kb/3aa88834-0641-4367-8994-985a86f01e55/resource/122bb3251be909d96d571c8eb26bdb0d/file/122bb3251be909d96d571c8eb26bdb0d/download/extracted/file_thumbnail', metadata=Metadata(metadata={}, language='en', languages=['en', 'zh'], status=<ResourceProcessingStatus.PROCESSED: 'PROCESSED'>), usermetadata=UserMetadata(classifications=[], relations=[]), fieldmetadata=[], computedmetadata=ComputedMetadata(field_classifications=[]), created=datetime.datetime(2025, 3, 4, 8, 51, 6, 159374), modified=None, last_seqid=0, last_account_seq=None, queue=<QueueType.PRIVATE: 'private'>, hidden=False, origin=None, extra=None, relations=None, data=ResourceData(texts=None, files={'122bb3251be909d96d571c8eb26bdb0d': FileFieldData(value=None, extracted=FileFieldExtractedData(text=ExtractedText(text=" \n UNITED STATES \n SECURITIES AND EXCHANGE COMMISSION \n \n Washington, D.C. 20549 \n \n FORM 10-Q \n (Mark One) \n \n ☒ QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 \n For the quarterly period ended June 25, 2022 \n \n or \n ☐ TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 \n \n For the transition period from to . \n Commission File Number: 001-36743 \n \n Apple Inc. \n (Exact name of Registrant as specified in its charter) \n \n California 94-2404110 \n (State or other jurisdiction \n \n of incorporation or organization) \n (I.R.S. Employer Identification No.) \n \n One Apple Park Way \n Cupertino, California 95014 \n \n (Address of principal executive offices) (Zip Code) \n \n (408) 996-1010 \n (Registrant's telephone number, including area code) \n \n Securities registered pursuant to Section 12(b) of the Act: \n \n Title of each class Trading symbol(s) Name of each exchange on which registered \n Common Stock, $0.00001 par value per share AAPL The Nasdaq Stock Market LLC \n \n 1.000% Notes due 2022 — The Nasdaq Stock Market LLC \n 1.375% Notes due 2024 — The Nasdaq Stock Market LLC \n 0.000% Notes due 2025 — The Nasdaq Stock Market LLC \n 0.875% Notes due 2025 — The Nasdaq Stock Market LLC \n 1.625% Notes due 2026 — The Nasdaq Stock Market LLC \n 2.000% Notes due 2027 — The Nasdaq Stock Market LLC \n 1.375% Notes due 2029 — The Nasdaq Stock Market LLC \n 3.050% Notes due 2029 — The Nasdaq Stock Market LLC \n 0.500% Notes due 2031 — The Nasdaq Stock Market LLC \n 3.600% Notes due 2042 — The Nasdaq Stock Market LLC \n \n Indicate by check mark whether the Registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 \n months (or for such shorter period that the Registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days. \n \n Yes ☒ No ☐ \n \n Indicate by check mark whether the Registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§232.405 of \n this chapter) during the preceding 12 months (or for such shorter period that the Registrant was required to submit such files). \n \n Yes ☒ No ☐ \n \n Indicate by check mark whether the Registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging growth company. \n See the definitions of large accelerated filer, accelerated filer, smaller reporting company, and emerging growth company in Rule 12b-2 of the Exchange Act. \n \n Large accelerated filer ☒ Accelerated filer ☐ \n Non-accelerated filer ☐ Smaller reporting company ☐ \n \n Emerging growth company ☐ \n \n \n  \n\n\n  \n\n\n A black apple logo on a white background. \n\n\n  \n If an emerging growth company, indicate by check mark if the Registrant has elected not to use the extended transition period for complying with any n ...
# Knowledge Graph saved to knowledge_graph.txt

# %% [markdown]
# # Exatracting the triplets

# %%
# Some imports

import requests
from tqdm import tqdm
import json

# %%
# Define headers for authentication and request type
headers = {
    "accept": "*/*",  # Accept all response types
    "accept-language": "en-US,en;q=0.9",  # Language preference
    "X-NUCLIA-SERVICEACCOUNT": f"Bearer {API_KEY}",  # Token for authentication
    "content-type": "application/json",  # Ensures we're sending JSON requests
    "x-ndb-client": "dashboard",  # Identifies the client making the request
}

# %%
# Make a GET request to fetch all resources from the knowledge box
response = requests.get(f"{KB_URL}/resources", headers=headers)

# Print the response status to check if the request was successful
print(f"Response Status Code: {response.status_code}")

# Handle unsuccessful requests by printing the error message and stopping execution
if response.status_code != 200:
    print(f"Error: {response.text}")
    raise Exception("Failed to fetch resources from Nuclia")

# Parse the JSON response and extract resource IDs
resources = response.json()
resources_ids = [resource["id"] for resource in resources.get("resources", [])]

# Display the number of resources found
print(f"Total Resources Found: {len(resources_ids)}")
# Out:
# Response Status Code: 200
# Total Resources Found: 20

# %%
# Initialize an empty list to store all relations
relations = []

# Iterate over each resource ID using tqdm for a progress bar
for resource_id in tqdm(resources_ids, desc="Extracting Relations"):
    # Construct the URL for fetching detailed resource data
    url = f"{KB_URL}/resource/{resource_id}?show=basic&show=origin&show=extracted"
    
    # Make a GET request to fetch the resource data
    response = requests.get(url, headers=headers)
    
    # If the request fails, print an error and continue to the next resource
    if response.status_code != 200:
        print(f"Error fetching resource {resource_id}: {response.text}")
        continue

    # Parse the JSON response
    result = response.json()
    
    # Extract relations from the resource
    for tag in ["links", "files", "texts"]:
        if tag in result["data"]:
            # Extract relations if metadata is present
            rels = [
                result["data"][tag][f]["extracted"]["metadata"]["metadata"]["relations"]
                for f in result["data"][tag]
                if "metadata" in result["data"][tag][f]["extracted"]
                and "metadata" in result["data"][tag][f]["extracted"]["metadata"]
            ]
            
            # Flatten the list (convert list of lists into a single list)
            rels = [item for sublist in rels for item in sublist]
            
            # Filter out relations that do not have "data_augmentation_task_id"
            rels = [rel for rel in rels if "data_augmentation_task_id" in rel["metadata"]]
            
            # Append the extracted relations to the main list
            relations.extend(rels)
            
            # Print how many relations were found for this specific tag
            print(f"{len(rels)} relations found in {tag} for resource {resource_id}")
# Out:
# Extracting Relations:   5%|▌         | 1/20 [00:00<00:13,  1.42it/s]
# 20 relations found in files for resource 122bb3251be909d96d571c8eb26bdb0d
# Extracting Relations:  10%|█         | 2/20 [00:01<00:15,  1.17it/s]
# 12 relations found in files for resource 15b46c0690d7d712e10ac7e9249cb6b0
# Extracting Relations:  15%|█▌        | 3/20 [00:02<00:13,  1.25it/s]
# 20 relations found in files for resource 1fb9be2040ab9fee044108559d76d180
# Extracting Relations:  20%|██        | 4/20 [00:02<00:11,  1.45it/s]
# 17 relations found in files for resource 2c6d707be547d4c782155dab5f345ea6
# Extracting Relations:  25%|██▌       | 5/20 [00:03<00:09,  1.61it/s]
# 11 relations found in files for resource 3be70c327392873c90d1ec326efd18b2
# Extracting Relations:  30%|███       | 6/20 [00:04<00:09,  1.54it/s]
# 13 relations found in files for resource 41406dceb9101e1c0745fd997023750c
# Extracting Relations:  35%|███▌      | 7/20 [00:04<00:08,  1.49it/s]
# 16 relations found in files for resource 50e68a434497f72e3d4efaa17327f518
# Extracting Relations:  40%|████      | 8/20 [00:05<00:07,  1.52it/s]
# 22 relations found in files for resource 5983e45cb65def99cc19803e44c1c08f
# Extracting Relations:  45%|████▌     | 9/20 [00:06<00:07,  1.57it/s]
# 13 relations found in files for resource 7feb9d1c9c95a834c3fc86b6ac812501
# Extracting Relations:  50%|█████     | 10/20 [00:06<00:06,  1.64it/s]
# 9 relations found in files for resource 8d459102137bb4e8aff40ef1345a15ee
# Extracting Relations:  55%|█████▌    | 11/20 [00:07<00:05,  1.71it/s]
# 19 relations found in files for resource 97902deb31e2ed0ec271e2fb6f8ec9fe
# Extracting Relations:  60%|██████    | 12/20 [00:08<00:05,  1.47it/s]
# 19 relations found in files for resource 9dffbbcc12d30952675acbbb979297c9
# Extracting Relations:  65%|██████▌   | 13/20 [00:09<00:05,  1.29it/s]
# 23 relations found in files for resource adfd263a79012c329df13f92b55183c8
# Extracting Relations:  70%|███████   | 14/20 [00:09<00:04,  1.30it/s]
# 3 relations found in files for resource bb4d14a9c64733e72326672373c2adf4
# Extracting Relations:  75%|███████▌  | 15/20 [00:10<00:03,  1.39it/s]
# 14 relations found in files for resource c84c56539abf45c8af9afb2f5cdbc1c1
# Extracting Relations:  80%|████████  | 16/20 [00:11<00:02,  1.40it/s]
# 6 relations found in files for resource d72209c97f912c5a1532d29c6de5a99a
# Extracting Relations:  85%|████████▌ | 17/20 [00:11<00:02,  1.39it/s]
# 62 relations found in files for resource d991a459b32a0707a71230538a58fa40
# Extracting Relations:  90%|█████████ | 18/20 [00:12<00:01,  1.47it/s]
# 6 relations found in files for resource df553f0167bb4d5ee5c8b7e21707cc23
# Extracting Relations:  95%|█████████▌| 19/20 [00:13<00:00,  1.43it/s]
# 40 relations found in files for resource e0017581e6b5ad04f1bf59c165042da9
# Extracting Relations: 100%|██████████| 20/20 [00:13<00:00,  1.44it/s]
# 15 relations found in files for resource f7c350c7131db23cdb0b0c1e5943a8ad

# %%
# Define the output file name
output_file = "relations.json"

# Save the extracted relations to a JSON file
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(relations, f, indent=4, ensure_ascii=False)

# Print confirmation message
print(f"Relations successfully saved to {output_file}")
# Out:
# Relations successfully saved to relations.json
